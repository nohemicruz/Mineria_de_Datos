# %%
import json
import pandas as pd
import numpy as np

# %%
base = pd.read_csv("unclean_data1.csv")
base = pd.read_csv("unclean_data1.csv",encoding='utf8')

# %%
base.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
base.shape
# Out:
# (14, 16)

# %%
base=base.rename(columns = {'movie_title':'titulo'})
base=base.rename(columns = {'num_critic_for_reviews':'num_criticas'})
base=base.rename(columns = {'duration':'duracion'})
base=base.rename(columns = {'DIRECTOR_facebook_likes':'num_likes_dir'})
base=base.rename(columns = {'ACTOR_1_facebook_likes':'num_likes_a1'})
base=base.rename(columns = {'actor_3_facebook_likes':'num_likes_a3'})
base=base.rename(columns = {'Cast_Total_facebook_likes':'tot_likes'})
base=base.rename(columns = {'facenumber_in_poster':'fn_poster'})
base=base.rename(columns = {'num_user_for_reviews':'num_rev'})
base=base.rename(columns = {'ACTOR_2_facebook_likes':'num_likes_a2'})
base
# Out:
#                                           titulo  num_criticas  duracion  \
# 0                                       Avatar?ÿ           723     178.0
# 1     Pirates of the Caribbean: At World's End?ÿ           302       NaN
# 2                                      Spectre?ÿ           602     148.0
# 3                        The Dark Knight Rises?ÿ           813       NaN
# 4                                  John Carter?ÿ           462     132.0
# 5                                 Spider-Man 3?ÿ           392     156.0
# 6                                      Tangled?ÿ           324       NaN
# 7                      Avengers: Age of Ultron?ÿ           635     141.0
# 8                      Avengers: Age of Ultron?ÿ           635     141.0
# 9       Harry Potter and the Half-Blood Prince?ÿ           375     153.0
# 10          Batman v Superman: Dawn of Justice?ÿ           673     183.0
# 11                            Superman Returns?ÿ           434     169.0
# ...

# %%
clase_duracion = base[base['duracion']>=150.0]
clase_duracion.to_csv('Agrupacion_duracion.csv',index=False)

# %%
base.duracion.unique()
# Out:
# array([178.,  nan, 148., 132., 156., 141., 153., 183., 169., 106., 151.])

# %% [markdown]
# ## Preguntas de Interes
#
# 1.-¿Para que me puede servir estas agrupaciones para la práctica siguiente?
#
# Elimina datos repetidos y facil manejo de informacion
#
# 2.-Importancia del analisis previo de los datos antes de iniciar las modificaciones.
# Mejor procesamientos de los datos
